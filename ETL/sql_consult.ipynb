# %%
from sqlalchemy import create_engine
import pandas as pd
db = create_engine('sqlite:///hm_db.sqlite')
conn = db.connect()
pd.read_sql_table('men_jeans',conn)
# Out:
#               id                                               link  \
# 0     1008549002  https://www2.hm.com/en_us/productpage.10085490...
# 1     1008549004  https://www2.hm.com/en_us/productpage.10085490...
# 2     1008549006  https://www2.hm.com/en_us/productpage.10085490...
# 3     1008549008  https://www2.hm.com/en_us/productpage.10085490...
# 4     1008549001  https://www2.hm.com/en_us/productpage.10085490...
# ...          ...                                                ...
# 2939  1004476006  https://www2.hm.com/en_us/productpage.10044760...
# 2940  0986779003  https://www2.hm.com/en_us/productpage.09867790...
# 2941  0986779004  https://www2.hm.com/en_us/productpage.09867790...
# 2942  0986779005  https://www2.hm.com/en_us/productpage.09867790...
# 2943  0986779002  https://www2.hm.com/en_us/productpage.09867790...
#
#                                name             color          fit  \
# 0                     regular_jeans        denim_blue  regular_fit
# ...

# %%
dados = pd.read_sql_table('men_jeans',conn)

# %%
dados['timestamp'].unique()
# Out:
# array(['2022-02-03 10:48', '2022-02-03 10:56', '2022-02-03 11:23',
#        '2022-02-03 11:30', '2022-02-03 11:39', '2022-02-03 12:14',
#        '2022-02-03 15:22', '2022-02-03 18:43', '2022-02-03 20:10',
#        '2022-02-03 22:44', '2022-02-04 13:40', '2022-02-04 14:26',
#        '2022-02-04 15:29', '2022-02-07 16:02', '2022-02-09 20:30',
#        '2022-02-09 21:07', '2022-02-09 21:17'], dtype=object)

# %%
15 15 * * * cd /Users/nando/Comunidade\ DS/ds_ao_dev && git add . && git commit -m 'updating database automatically' && git push origin master
